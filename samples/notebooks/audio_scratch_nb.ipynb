# %%
# %pylab inline

from __future__ import division # the python 3 division - outputs double instead of am int
from __future__ import print_function # the python 3 print function - print()
from tqdm import tqdm # library add a progrees bar for an iterating for loops

from librosa.feature import melspectrogram

import time,datetime # librraies to keep track of times
import threading  # library for multithreading workloads

import os    #
import wave  # library for recording sound and exporting as a wave file
import alsaaudio, audioop, sys, librosa  # library for recording sound

import numpy as np # python's standard linear algebra library: needed for static arrays
import pandas as pd    # library for importing from csv files
import matplotlib.pyplot as plt # library for graphing data
import torch as th    # a python version of Lua's Torch ML library.
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
y, sr = librosa.load("../in_Data/rattleAlone_0.wav")
S = melspectrogram(y,sr,n_mels=128)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattleAlone_0.png')
np.savetxt('../out_Data/csv/rattleAlone_0.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattleAlone_1.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time', )
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattleAlone_1.png')
np.savetxt('../out_Data/csv/rattleAlone_1.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattleAlone_2.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattleAlone_2.png')
np.savetxt('../out_Data/csv/rattleAlone_2.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattleAlone_3.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattleAlone_3.png')
np.savetxt('../out_Data/csv/rattleAlone_3.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattle_2017-02-08_16:27:01.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattle_2017-02-08_16:27:01.png')
np.savetxt('../out_Data/csv/rattle_2017-02-08_16:27:01.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattle_2017-02-08_16:29:18.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattle_2017-02-08_16:29:18.png')
np.savetxt('../out_Data/csv/rattle_2017-02-08_16:29:18.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattle_2017-02-08_16:30:56.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattle_2017-02-08_16:30.56.png')
np.savetxt('../out_Data/csv/rattle_2017-02-08_16:30.56.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattle_2017-02-08_16:37:54.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattle_2017-02-08_16:37.54.png')
np.savetxt('../out_Data/csv/rattle_2017-02-08_16:37.54.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattle_2017-02-14_13:26:19.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

plt.savefig('../out_Data/png/rattle_2017-02-08_13:26:19.png')
np.savetxt('../out_Data/csv/rattle_2017-02-08_13:26:19.csv', S,delimiter=',',fmt='%.3e')

# %%
y, sr = librosa.load("../in_Data/rattle_2017-02-14_14:37:53.wav")
S = melspectrogram(y,sr)

librosa.display.specshow(librosa.logamplitude(S),
                        y_axis='mel',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()
plt.savefig('../out_Data/png/rattle_2017-02-08_14:37:53.png')
np.savetxt('../out_Data/csv/rattle_2017-02-08_14:37:53.csv', S,delimiter=',',fmt='%.3e')

# %%
# audio recording setup
# creates a new wavefile for each run
def outFile():
    return "../in_Data/{}_rattle.wav".format(datetime.datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d_%H:%M:%S'))

# %%
string = outFile()
string = string.replace('.wav','.csv')
string = string.replace('in','out')
string
# Out:
# '../out_Data/2017-02-15_16:59:05_rattle.csv'
